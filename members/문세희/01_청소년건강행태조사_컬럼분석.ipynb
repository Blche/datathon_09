# %% [markdown]
# ## 데이터 read & info 확인

# %%
# 기본
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 메모리
import gc

# 그래프 설정
sns.set()

# 그래프 기본 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
# plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['figure.figsize'] = 12, 6
plt.rcParams['font.size'] = 13
plt.rcParams['axes.unicode_minus'] = False

# %%
# 데이터프레임을 넣고 column별 특성 및 결측값, 고유값들을 확인하는 함수 사용

def resumetable(df, n):
    print(f'데이터셋 크기: {df.shape}')                                # 데이터프레임의 전체 크기(행, 열) 출력

    summary = pd.DataFrame(df.dtypes, columns=['데이터 타입'])         # 각 피처의 데이터 타입을 가져와 데이터프레임으로 생성
    summary = summary.reset_index()                                    # 인덱스를 초기화하여 컬럼으로 변환
    summary = summary.rename(columns={'index':'피처'})                 # 'index' 컬럼명을 '피처'로 변경

    summary['결측값 개수'] = df.isnull().sum().values                 # 각 피처의 결측값(null) 개수 계산
    summary['고유값 개수'] = df.nunique().values                      # 각 피처의 고유값 개수 계산
    
    for i in range(n):
        summary[f"{i+1}번째 값"] = df.iloc[i].values
    
    return summary                                                     # 요약 테이블 반환

# %%
# 불필요한 컬럼 drop 후 메인 데이터 읽어오기
df = pd.read_csv('02_데이터셋/청소년건강행태조사/kyrbs2024_sas/kyrbs2024_수정.csv')

# %%
with pd.option_context('display.max_rows', None):
    display(resumetable(df, 5))
# Out:
# 데이터셋 크기: (54653, 57)
#                    피처   데이터 타입  결측값 개수  고유값 개수    1번째 값    2번째 값    3번째 값  \
# 0                 OBS   object       0   54653  A100001  A100002  A100003
# 1                조사연도  float64       0       1   2024.0   2024.0   2024.0
# 2                  시도   object       0      17       서울       서울       서울
# 3                도시규모   object       0       3      대도시      대도시      대도시
# 4                학교구분   object       0       2      중학교      중학교      중학교
# 5                학교유형   object       0       3     남녀공학     남녀공학     남녀공학
# 6                 지역군   object       0      49   서울대4-3   서울대4-3   서울대4-3
# 7           주관적_건강_인지  float64       0       5      1.0      1.0      1.0
# 8           주관적_체형_인지  float64       0       5      2.0      4.0      3.0
# 9            평생_흡연_경험  float64       0       2      1.0      1.0      1.0
# 10           처음_흡연_시기  float64      87      14   9999.0   9999.0   9999.0
# 11               흡연일수  float64       0       8   9999.0   9999.0   9999.0
# 12        매일_흡연_시작_시기  float64      32      13   9999.0   9999.0   9999.0
# 13                흡연량  float64       0       7   9999.0   9999.0   9999.0
# 14            전자담배_경험  float64       0       2      1.0      1.0      1.0
# 15      전자담배_처음_사용_시기  float64      30      14   9999.0   9999.0   9999.0
# 16       전자담배_현재_사용일수  float64       0       8   9999.0   9999.0   9999.0
# 17      전자담배_매일_사용_시기  float64      23      13   9999.0   9999.0   9999.0
# 18        궐련형_전자담배_경험  float64       0       2      1.0      1.0      1.0
# 19  궐련형_전자담배_처음_사용_시기  float64      32      14   9999.0   9999.0   9999.0
# 20   궐련형_전자담배_현재_사용일수  float64       0       8   9999.0   9999.0   9999.0
# 21  궐련형_전자담배_매일_사용_시기  float64      15      11   9999.0   9999.0   9999.0
# 22       궐련형_전자담배_흡연량  float64       0       7   9999.0   9999.0   9999.0
# 23            주된_흡연장소  float64       0       6   9999.0   9999.0   9999.0
# 24           담배_구매_방법  float64       0       6   9999.0   9999.0   9999.0
# 25          담배_구매_용이성  float64       0       5      1.0      1.0      1.0
# 26           금연_시도_여부  float64       0       3   9999.0   9999.0   9999.0
# 27            금연홍보_없음  float64       0       2   9999.0   9999.0   9999.0
# 28            금연홍보_TV  float64       0       2      2.0      2.0      2.0
# 29           금연홍보_라디오  float64       0       2   9999.0   9999.0      3.0
# 30         금연홍보_TV_뉴스  float64       0       2      4.0   9999.0      4.0
# 31           금연홍보_인터넷  float64       0       2      5.0   9999.0      5.0
# 32            금연홍보_신문  float64       0       2      6.0   9999.0      6.0
# 33          금연홍보_대중교통  float64       0       2      7.0   9999.0      7.0
# 34            담배광고_잡지  float64       0       2      1.0   9999.0   9999.0
# 35           담배광고_인터넷  float64       0       2      2.0      2.0   9999.0
# 36           담배광고_편의점  float64       0       2      3.0   9999.0   9999.0
# 37          담배광고_슈퍼마켓  float64       0       2      4.0   9999.0   9999.0
# 38            담배광고_없음  float64       0       2   9999.0   9999.0      5.0
# 39            가정_간접흡연  float64       0       8      1.0      8.0      1.0
# 40            학교_간접흡연  float64       0       8      1.0      1.0      1.0
# 41          공공장소_간접흡연  float64       0       8      1.0      3.0      1.0
# 42         학교_금연교육_경험  float64       0       2      2.0      2.0      2.0
# 43            가족흡연_없음  float64       0       2      1.0   9999.0   9999.0
# 44           가족흡연_아버지  float64       0       2   9999.0      2.0      2.0
# 45           가족흡연_어머니  float64       0       2   9999.0   9999.0   9999.0
# 46          가족흡연_형제자매  float64       0       2   9999.0   9999.0   9999.0
# 47           가족흡연_조부모  float64       0       2   9999.0      5.0   9999.0
# 48            가족흡연_기타  float64       0       2   9999.0   9999.0   9999.0
# 49            가족흡연_모름  float64       0       2   9999.0   9999.0   9999.0
# 50              친구_흡연  float64       0       4      1.0      1.0      1.0
# 51                만나이  float64      49       7     13.0     13.0     13.0
# 52                 월령  float64      49      83    158.0    161.0    161.0
# 53               학업성적  float64       3       5      1.0      4.0      1.0
# 54               경제상태  float64       5       5      1.0      2.0      1.0
# 55               거주형태  float64       7       5      1.0      1.0      1.0
# 56                 학년  float64       0       6      1.0      1.0      1.0
#
#       4번째 값    5번째 값
# 0   A100004  A100005
# 1    2024.0   2024.0
# 2        서울       서울
# 3       대도시      대도시
# 4       중학교      중학교
# 5      남녀공학     남녀공학
# 6    서울대4-3   서울대4-3
# 7       4.0      2.0
# 8       4.0      4.0
# 9       1.0      1.0
# 10   9999.0   9999.0
# 11   9999.0   9999.0
# 12   9999.0   9999.0
# 13   9999.0   9999.0
# 14      1.0      1.0
# 15   9999.0   9999.0
# 16   9999.0   9999.0
# 17   9999.0   9999.0
# 18      1.0      1.0
# 19   9999.0   9999.0
# 20   9999.0   9999.0
# 21   9999.0   9999.0
# 22   9999.0   9999.0
# 23   9999.0   9999.0
# 24   9999.0   9999.0
# 25      1.0      1.0
# 26   9999.0   9999.0
# 27   9999.0      1.0
# 28      2.0   9999.0
# 29   9999.0   9999.0
# 30   9999.0   9999.0
# 31      5.0   9999.0
# 32   9999.0   9999.0
# 33      7.0   9999.0
# 34   9999.0   9999.0
# 35      2.0   9999.0
# 36   9999.0      3.0
# 37   9999.0   9999.0
# 38   9999.0   9999.0
# 39      1.0      1.0
# 40      1.0      1.0
# 41      4.0      2.0
# 42      2.0      2.0
# 43   9999.0      1.0
# 44      2.0   9999.0
# 45   9999.0   9999.0
# 46   9999.0   9999.0
# 47   9999.0   9999.0
# 48   9999.0   9999.0
# 49   9999.0   9999.0
# 50      1.0      1.0
# 51     13.0     13.0
# 52    159.0    159.0
# 53      2.0      2.0
# 54      2.0      3.0
# 55      1.0      1.0
# 56      1.0      1.0

# %% [markdown]
# ## 결측치 확인

# %%
import missingno as msno

# 결측치 막대그래프
msno.bar(df)
plt.show()

# 결측치 히트맵 (상관된 결측치 패턴 확인)
msno.heatmap(df)
plt.show()

# 결측치 매트릭스 (결측 분포 확인)
msno.matrix(df)
plt.show()

# %%
# 결측치 있는 컬럼
nan_cols = df.columns[df.isnull().any()]
print(df[nan_cols].isnull().sum())
# Out:
# 처음_흡연_시기             87
# 매일_흡연_시작_시기          32
# 전자담배_처음_사용_시기        30
# 전자담배_매일_사용_시기        23
# 궐련형_전자담배_처음_사용_시기    32
# 궐련형_전자담배_매일_사용_시기    15
# 만나이                  49
# 월령                   49
# 학업성적                  3
# 경제상태                  5
# 거주형태                  7
# dtype: int64

# %%
# 결측치 있는 컬럼 값 분석
for col in nan_cols:
    print(f"\n[ {col} ]")
    print(df[col].value_counts(dropna=False))
# Out:
# [ 처음_흡연_시기 ]
# 처음_흡연_시기
# 9999.0    50442
# 9.0         960
# 8.0         945
# 10.0        629
# 11.0        500
# 7.0         368
# 12.0        207
# 1.0         171
# 6.0         122
# 13.0         91
# NaN          87
# 5.0          64
# 4.0          41
# 3.0          17
# 2.0           9
# Name: count, dtype: int64
#
# [ 매일_흡연_시작_시기 ]
# 매일_흡연_시작_시기
# 9999.0    53813
# 9.0         182
# 11.0        164
# 10.0        153
# 8.0         134
# 12.0         63
# 1.0          43
# 7.0          36
# NaN          32
# 13.0         17
# 6.0           8
# 5.0           4
# 2.0           2
# 4.0           2
# Name: count, dtype: int64
#
# [ 전자담배_처음_사용_시기 ]
# 전자담배_처음_사용_시기
# 9999.0    51028
# 9.0         814
# 10.0        693
# 8.0         683
# 11.0        553
# 12.0        266
# 7.0         195
# 13.0        105
# 1.0          93
# 6.0          56
# 4.0          44
# 3.0          38
# NaN          30
# 5.0          29
# 2.0          26
# Name: count, dtype: int64
#
# [ 전자담배_매일_사용_시기 ]
# 전자담배_매일_사용_시기
# 9999.0    54214
# 11.0         96
# 10.0         78
# 9.0          67
# 12.0         54
# 8.0          45
# 1.0          33
# NaN          23
# 13.0         20
# 7.0          14
# 6.0           4
# 5.0           3
# 2.0           1
# 4.0           1
# Name: count, dtype: int64
#
# [ 궐련형_전자담배_처음_사용_시기 ]
# 궐련형_전자담배_처음_사용_시기
# 9999.0    52638
# 11.0        439
# 10.0        354
# 9.0         343
# 12.0        230
# 8.0         215
# 13.0         95
# 1.0          88
# 7.0          78
# 2.0          34
# 3.0          33
# NaN          32
# 4.0          30
# 5.0          28
# 6.0          16
# Name: count, dtype: int64
#
# [ 궐련형_전자담배_매일_사용_시기 ]
# 궐련형_전자담배_매일_사용_시기
# 9999.0    54461
# 11.0         44
# 1.0          30
# 10.0         24
# 13.0         24
# 12.0         20
# 9.0          16
# NaN          15
# 8.0           9
# 7.0           5
# 5.0           3
# 6.0           2
# Name: count, dtype: int64
#
# [ 만나이 ]
# 만나이
# 13.0    9897
# 14.0    9437
# 15.0    9270
# 16.0    9027
# 17.0    8181
# 12.0    4766
# 18.0    4026
# NaN       49
# Name: count, dtype: int64
#
# [ 월령 ]
# 월령
# 161.0    1009
# 185.0     932
# 159.0     929
# 173.0     912
# 197.0     904
#          ...
# 148.0       8
# 224.0       3
# 147.0       2
# 144.0       1
# 145.0       1
# Name: count, Length: 84, dtype: int64
#
# [ 학업성적 ]
# 학업성적
# 3.0    15844
# 2.0    13811
# 4.0    12676
# 1.0     7027
# 5.0     5292
# NaN        3
# Name: count, dtype: int64
#
# [ 경제상태 ]
# 경제상태
# 3.0    25431
# 2.0    16814
# 1.0     6329
# 4.0     4979
# 5.0     1095
# NaN        5
# Name: count, dtype: int64
#
# [ 거주형태 ]
# 거주형태
# 1.0    51961
# 4.0     1830
# 3.0      330
# 2.0      312
# 5.0      213
# NaN        7
# Name: count, dtype: int64

# %% [markdown]
# ### 결측치 처리 : 최빈값

# %%
nancol = '거주형태'

# %%
df[nancol].mode()
# Out:
# 0    1.0
# Name: 거주형태, dtype: float64

# %%
df.fillna(3.0, inplace=True)
with pd.option_context('display.max_rows', None):
    display(df[nancol].value_counts(dropna=False))
# Out:
# 학업성적
# 3.0       15844
# 2.0       13811
# 4.0       12676
# 1.0        7027
# 5.0        5292
# 9999.0        3
# Name: count, dtype: int64

# %%
df[nancol].replace(9999.0, 1.0, inplace=True)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_23112\881934370.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[nancol].replace(9999.0, 1.0, inplace=True)

# %%
df[nancol].value_counts(dropna=False)
# Out:
# 거주형태
# 1.0    51968
# 4.0     1830
# 3.0      330
# 2.0      312
# 5.0      213
# Name: count, dtype: int64

# %%
resumetable(df,5)
# Out:
# 데이터셋 크기: (54653, 57)
#                    피처   데이터 타입  결측값 개수  고유값 개수    1번째 값    2번째 값    3번째 값  \
# 0                 OBS   object       0   54653  A100001  A100002  A100003
# 1                조사연도  float64       0       1   2024.0   2024.0   2024.0
# 2                  시도   object       0      17       서울       서울       서울
# 3                도시규모   object       0       3      대도시      대도시      대도시
# 4                학교구분   object       0       2      중학교      중학교      중학교
# 5                학교유형   object       0       3     남녀공학     남녀공학     남녀공학
# 6                 지역군   object       0      49   서울대4-3   서울대4-3   서울대4-3
# 7           주관적_건강_인지  float64       0       5      1.0      1.0      1.0
# 8           주관적_체형_인지  float64       0       5      2.0      4.0      3.0
# 9            평생_흡연_경험  float64       0       2      1.0      1.0      1.0
# 10           처음_흡연_시기  float64       0      14   9999.0   9999.0   9999.0
# 11               흡연일수  float64       0       8   9999.0   9999.0   9999.0
# 12        매일_흡연_시작_시기  float64       0      13   9999.0   9999.0   9999.0
# 13                흡연량  float64       0       7   9999.0   9999.0   9999.0
# 14            전자담배_경험  float64       0       2      1.0      1.0      1.0
# 15      전자담배_처음_사용_시기  float64       0      14   9999.0   9999.0   9999.0
# 16       전자담배_현재_사용일수  float64       0       8   9999.0   9999.0   9999.0
# 17      전자담배_매일_사용_시기  float64       0      13   9999.0   9999.0   9999.0
# 18        궐련형_전자담배_경험  float64       0       2      1.0      1.0      1.0
# 19  궐련형_전자담배_처음_사용_시기  float64       0      14   9999.0   9999.0   9999.0
# 20   궐련형_전자담배_현재_사용일수  float64       0       8   9999.0   9999.0   9999.0
# 21  궐련형_전자담배_매일_사용_시기  float64       0      11   9999.0   9999.0   9999.0
# 22       궐련형_전자담배_흡연량  float64       0       7   9999.0   9999.0   9999.0
# 23            주된_흡연장소  float64       0       6   9999.0   9999.0   9999.0
# 24           담배_구매_방법  float64       0       6   9999.0   9999.0   9999.0
# 25          담배_구매_용이성  float64       0       5      1.0      1.0      1.0
# 26           금연_시도_여부  float64       0       3   9999.0   9999.0   9999.0
# 27            금연홍보_없음  float64       0       2   9999.0   9999.0   9999.0
# 28            금연홍보_TV  float64       0       2      2.0      2.0      2.0
# 29           금연홍보_라디오  float64       0       2   9999.0   9999.0      3.0
# 30         금연홍보_TV_뉴스  float64       0       2      4.0   9999.0      4.0
# 31           금연홍보_인터넷  float64       0       2      5.0   9999.0      5.0
# 32            금연홍보_신문  float64       0       2      6.0   9999.0      6.0
# 33          금연홍보_대중교통  float64       0       2      7.0   9999.0      7.0
# 34            담배광고_잡지  float64       0       2      1.0   9999.0   9999.0
# 35           담배광고_인터넷  float64       0       2      2.0      2.0   9999.0
# 36           담배광고_편의점  float64       0       2      3.0   9999.0   9999.0
# 37          담배광고_슈퍼마켓  float64       0       2      4.0   9999.0   9999.0
# 38            담배광고_없음  float64       0       2   9999.0   9999.0      5.0
# 39            가정_간접흡연  float64       0       8      1.0      8.0      1.0
# 40            학교_간접흡연  float64       0       8      1.0      1.0      1.0
# 41          공공장소_간접흡연  float64       0       8      1.0      3.0      1.0
# 42         학교_금연교육_경험  float64       0       2      2.0      2.0      2.0
# 43            가족흡연_없음  float64       0       2      1.0   9999.0   9999.0
# 44           가족흡연_아버지  float64       0       2   9999.0      2.0      2.0
# 45           가족흡연_어머니  float64       0       2   9999.0   9999.0   9999.0
# 46          가족흡연_형제자매  float64       0       2   9999.0   9999.0   9999.0
# 47           가족흡연_조부모  float64       0       2   9999.0      5.0   9999.0
# 48            가족흡연_기타  float64       0       2   9999.0   9999.0   9999.0
# 49            가족흡연_모름  float64       0       2   9999.0   9999.0   9999.0
# 50              친구_흡연  float64       0       4      1.0      1.0      1.0
# 51                만나이  float64       0       7     13.0     13.0     13.0
# 52                 월령  float64       0      83    158.0    161.0    161.0
# 53               학업성적  float64       0       5      1.0      4.0      1.0
# 54               경제상태  float64       0       5      1.0      2.0      1.0
# 55               거주형태  float64       0       5      1.0      1.0      1.0
# 56                 학년  float64       0       6      1.0      1.0      1.0
#
#       4번째 값    5번째 값
# 0   A100004  A100005
# 1    2024.0   2024.0
# 2        서울       서울
# 3       대도시      대도시
# 4       중학교      중학교
# 5      남녀공학     남녀공학
# 6    서울대4-3   서울대4-3
# 7       4.0      2.0
# 8       4.0      4.0
# 9       1.0      1.0
# 10   9999.0   9999.0
# 11   9999.0   9999.0
# 12   9999.0   9999.0
# 13   9999.0   9999.0
# 14      1.0      1.0
# 15   9999.0   9999.0
# 16   9999.0   9999.0
# 17   9999.0   9999.0
# 18      1.0      1.0
# 19   9999.0   9999.0
# 20   9999.0   9999.0
# 21   9999.0   9999.0
# 22   9999.0   9999.0
# 23   9999.0   9999.0
# 24   9999.0   9999.0
# 25      1.0      1.0
# 26   9999.0   9999.0
# 27   9999.0      1.0
# 28      2.0   9999.0
# 29   9999.0   9999.0
# 30   9999.0   9999.0
# 31      5.0   9999.0
# 32   9999.0   9999.0
# 33      7.0   9999.0
# 34   9999.0   9999.0
# 35      2.0   9999.0
# 36   9999.0      3.0
# 37   9999.0   9999.0
# 38   9999.0   9999.0
# 39      1.0      1.0
# 40      1.0      1.0
# 41      4.0      2.0
# 42      2.0      2.0
# 43   9999.0      1.0
# 44      2.0   9999.0
# 45   9999.0   9999.0
# 46   9999.0   9999.0
# 47   9999.0   9999.0
# 48   9999.0   9999.0
# 49   9999.0   9999.0
# 50      1.0      1.0
# 51     13.0     13.0
# 52    159.0    159.0
# 53      2.0      2.0
# 54      2.0      3.0
# 55      1.0      1.0
# 56      1.0      1.0

# %% [markdown]
# # 컬럼 하나씩 확인

# %% [markdown]
# ## 전체 시각화

# %%
# 컬럼 시각화 확인용 함수 생성
def visualize_columns(df, target=None):
    for col in df.columns:
        plt.figure(figsize=(8, 4))
        
        if df[col].dtype == 'object' or df[col].nunique() < 15:
            # 범주형 변수
            sns.countplot(data=df, x=col, hue=target if target else None)
            plt.title(f'Count Plot of {col}')
            plt.xticks(rotation=45)
        
        else:
            # 수치형 변수
            sns.histplot(df[col].dropna(), kde=True)
            plt.title(f'Distribution of {col}')
        
        plt.tight_layout()
        plt.show()

# %%
df_viz = df.copy()

# %%
# 데이터 시각화의 편의성을 위해 9999.0을 nan으로 변경
df_viz.replace(9999.0, np.nan, inplace=True)

# %%
resumetable(df_viz,3)
# Out:
# 데이터셋 크기: (54653, 57)
#                    피처   데이터 타입  결측값 개수  고유값 개수    1번째 값    2번째 값    3번째 값
# 0                 OBS   object       0   54653  A100001  A100002  A100003
# 1                조사연도  float64       0       1   2024.0   2024.0   2024.0
# 2                  시도   object       0      17       서울       서울       서울
# 3                도시규모   object       0       3      대도시      대도시      대도시
# 4                학교구분   object       0       2      중학교      중학교      중학교
# 5                학교유형   object       0       3     남녀공학     남녀공학     남녀공학
# 6                 지역군   object       0      49   서울대4-3   서울대4-3   서울대4-3
# 7           주관적_건강_인지  float64       0       5      1.0      1.0      1.0
# 8           주관적_체형_인지  float64       0       5      2.0      4.0      3.0
# 9            평생_흡연_경험  float64       0       2      1.0      1.0      1.0
# 10           처음_흡연_시기  float64   50529      13      NaN      NaN      NaN
# 11               흡연일수  float64   50442       7      NaN      NaN      NaN
# 12        매일_흡연_시작_시기  float64   53845      12      NaN      NaN      NaN
# 13                흡연량  float64   52711       6      NaN      NaN      NaN
# 14            전자담배_경험  float64       0       2      1.0      1.0      1.0
# 15      전자담배_처음_사용_시기  float64   51058      13      NaN      NaN      NaN
# 16       전자담배_현재_사용일수  float64   51028       7      NaN      NaN      NaN
# 17      전자담배_매일_사용_시기  float64   54237      12      NaN      NaN      NaN
# 18        궐련형_전자담배_경험  float64       0       2      1.0      1.0      1.0
# 19  궐련형_전자담배_처음_사용_시기  float64   52670      13      NaN      NaN      NaN
# 20   궐련형_전자담배_현재_사용일수  float64   52638       7      NaN      NaN      NaN
# 21  궐련형_전자담배_매일_사용_시기  float64   54476      10      NaN      NaN      NaN
# 22       궐련형_전자담배_흡연량  float64   53658       6      NaN      NaN      NaN
# 23            주된_흡연장소  float64   52232       5      NaN      NaN      NaN
# 24           담배_구매_방법  float64   52232       5      NaN      NaN      NaN
# 25          담배_구매_용이성  float64       0       5      1.0      1.0      1.0
# 26           금연_시도_여부  float64   52232       2      NaN      NaN      NaN
# 27            금연홍보_없음  float64   38839       1      NaN      NaN      NaN
# 28            금연홍보_TV  float64   27276       1      2.0      2.0      2.0
# 29           금연홍보_라디오  float64   49322       1      NaN      NaN      3.0
# 30         금연홍보_TV_뉴스  float64   43375       1      4.0      NaN      4.0
# 31           금연홍보_인터넷  float64   31306       1      5.0      NaN      5.0
# 32            금연홍보_신문  float64   47918       1      6.0      NaN      6.0
# 33          금연홍보_대중교통  float64   41544       1      7.0      NaN      7.0
# 34            담배광고_잡지  float64   50569       1      1.0      NaN      NaN
# 35           담배광고_인터넷  float64   34786       1      2.0      2.0      NaN
# 36           담배광고_편의점  float64   30626       1      3.0      NaN      NaN
# 37          담배광고_슈퍼마켓  float64   44743       1      4.0      NaN      NaN
# 38            담배광고_없음  float64   35237       1      NaN      NaN      5.0
# 39            가정_간접흡연  float64       0       8      1.0      8.0      1.0
# 40            학교_간접흡연  float64       0       8      1.0      1.0      1.0
# 41          공공장소_간접흡연  float64       0       8      1.0      3.0      1.0
# 42         학교_금연교육_경험  float64       0       2      2.0      2.0      2.0
# 43            가족흡연_없음  float64   29280       1      1.0      NaN      NaN
# 44           가족흡연_아버지  float64   32631       1      NaN      2.0      2.0
# 45           가족흡연_어머니  float64   52329       1      NaN      NaN      NaN
# 46          가족흡연_형제자매  float64   51886       1      NaN      NaN      NaN
# 47           가족흡연_조부모  float64   50850       1      NaN      5.0      NaN
# 48            가족흡연_기타  float64   51061       1      NaN      NaN      NaN
# 49            가족흡연_모름  float64   53025       1      NaN      NaN      NaN
# 50              친구_흡연  float64       0       4      1.0      1.0      1.0
# 51                만나이  float64       0       7     13.0     13.0     13.0
# 52                 월령  float64       0      83    158.0    161.0    161.0
# 53               학업성적  float64       0       5      1.0      4.0      1.0
# 54               경제상태  float64       0       5      1.0      2.0      1.0
# 55               거주형태  float64       0       5      1.0      1.0      1.0
# 56                 학년  float64       0       6      1.0      1.0      1.0

# %%
exclude_cols = ['OBS', '조사연도']
viz_subset = df_viz.drop(columns=exclude_cols)

# %%
visualize_columns(viz_subset)

# %% [markdown]
# ## 숫자로 항목화된 컬럼 파악

# %%
df2 = df.copy()

# %%
# 데이터 시각화의 편의성을 위해 9999.0을 nan으로 변경
df2.replace(9999.0, np.nan, inplace=True)

# %% [markdown]
# ### 주관적 건강 인지

# %% [raw]
# [PR_HT] 1. 평상시 자신의 건강상태가 어떻다고 생각합니까?
# [1] ① 매우 건강한 편이다
# [2] ② 건강한 편이다
# [3] ③ 보통이다
# [4] ④ 건강하지 못한 편이다
# [5] ⑤ 매우 건강하지 못한 편이다

# %% [markdown]
# - 숫자가 작을수록 건강

# %% [markdown]
# ### 주관적 체형 인지

# %% [raw]
# [PR_BI] 2. 자신의 체형이 어떻다고 생각합니까?
# [1] ① 매우 마른 편이다
# [2] ② 약간 마른 편이다
# [3] ③ 보통이다
# [4] ④ 약간 살이 찐 편이다
# [5] ⑤ 매우 살이 찐 편이다

# %% [markdown]
# - 작으면 마름, 크면 살찐 편

# %% [markdown]
# ## 담배

# %% [markdown]
# ### 평생 흡연 경험

# %% [markdown]
# - 1.0 : 있다
# - 2.0 : 없다

# %%
# 복사본 기준 처리
df2["변환_평생_흡연_경험"] = df2["평생_흡연_경험"] == 1.0

# %%
df2['변환_평생_흡연_경험'].value_counts()
# Out:
# 변환_평생_흡연_경험
# True     50442
# False     4211
# Name: count, dtype: int64

# %% [markdown]
# ### 처음 흡연 시기

# %% [raw]
# - 처음_흡연_시기
# [TC_FAGE] 55. 처음으로 일반담배(궐련)를 한 두 모금이라도 피워본 때는 언제입니까?
# [1] ① 초등학교 입학 전
# [2] ② 초등학교 1학년
# [3] ③ 초등학교 2학년
# [4] ④ 초등학교 3학년
# [5] ⑤ 초등학교 4학년
# [6] ⑥ 초등학교 5학년
# [7] ⑦ 초등학교 6학년
# [8] ⑧ 중학교 1학년
# [9] ⑨ 중학교 2학년
# [10] ⑩ 중학교 3학년
# [11] ⑪ 고등학교 1학년
# [12] ⑫ 고등학교 2학년
# [13] ⑬ 고등학교 3학년

# %%
TC_FAGE = {
    1.0: "초등학교 입학 전",
    2.0: "초등학교 1학년",
    3.0: "초등학교 2학년",
    4.0: "초등학교 3학년",
    5.0: "초등학교 4학년",
    6.0: "초등학교 5학년",
    7.0: "초등학교 6학년",
    8.0: "중학교 1학년",
    9.0: "중학교 2학년",
    10.0: "중학교 3학년",
    11.0: "고등학교 1학년",
    12.0: "고등학교 2학년",
    13.0: "고등학교 3학년"
}

# %%
df2["변환_처음_흡연_시기"] = df2["처음_흡연_시기"].map(TC_FAGE)

# %% [markdown]
# ### 흡연일수

# %% [raw]
# - 최근 30일, 일반담배 피운 날수
# [1] ① 최근 30일 동안 없다
# [2] ② 월 1~2일
# [3] ③ 월 3~5일
# [4] ④ 월 6~9일
# [5] ⑤ 월 10~19일
# [6] ⑥ 월 20~29일
# [7] ⑦ 매일
# [9999] 일반담배 피워본 적 없음

# %% [markdown]
# - 흡연일수에서 1을 선택한 이들은 메인 흡연층은 아니라고 봐야 함

# %% [markdown]
# ### 매일 흡연 시작 시기

# %% [markdown]
# - '흡연일수'에서 매일 흡연한다고 응답한 이들만

# %% [raw]
# [TC_DAGE] 55. 일반담배(궐련)를 매일 피우기 시작한 때는 언제입니까?
# [1] ① 초등학교 입학 전
# [2] ② 초등학교 1학년
# [3] ③ 초등학교 2학년
# [4] ④ 초등학교 3학년
# [5] ⑤ 초등학교 4학년
# [6] ⑥ 초등학교 5학년
# [7] ⑦ 초등학교 6학년
# [8] ⑧ 중학교 1학년
# [9] ⑨ 중학교 2학년
# [10] ⑩ 중학교 3학년
# [11] ⑪ 고등학교 1학년
# [12] ⑫ 고등학교 2학년
# [13] ⑬ 고등학교 3학년

# %%
# 항목이 동일하므로 '처음_흡연_시작_시기'와 똑같이 매핑
df2["변환_매일_흡연_시작_시기"] = df2["매일_흡연_시작_시기"].map(TC_FAGE)

# %%
grade_order = [
    '초등학교 입학 전',
    '초등학교 1학년',
    '초등학교 2학년',
    '초등학교 3학년',
    '초등학교 4학년',
    '초등학교 5학년',
    '초등학교 6학년',
    '중학교 1학년',
    '중학교 2학년',
    '중학교 3학년',
    '고등학교 1학년',
    '고등학교 2학년',
    '고등학교 3학년'
]

# sns.countplot(data=df2, x='변환_매일_흡연_시작_시기', order=grade_order)
# plt.xticks(rotation=45);
grade_counts = df2['변환_매일_흡연_시작_시기'].value_counts().reindex(grade_order)
sns.lineplot(x=grade_counts.index, y=grade_counts.values, marker='o')
plt.xticks(rotation=45);

# %% [markdown]
# ### 흡연량

# %% [markdown]
# - 흡연일수에서 최근 30일 동안 피웠다고 대답한 이들만

# %% [raw]
# [TC_AMNT] 58. 최근 30일 동안, 일반담배(궐련)를 하루에 평균 몇 개비 피웠습니까?
# [1] ① 1개비 미만/1일
# [2] ② 1개비/1일
# [3] ③ 2~5개비/1일
# [4] ④ 6~9개비/1일
# [5] ⑤ 10~19개비/1일
# [6] ⑥ 20개비 이상/1일"

# %% [markdown]
# - 1일수록 적게 피우는 이들

# %% [markdown]
# ## 전자담배 : 담배와 똑같이 처리

# %% [markdown]
# ### 전자담배 경험

# %%
# boolean으로
df2["변환_전자담배_경험"] = df2["전자담배_경험"] == 1.0

# %% [markdown]
# ### 전자담배 처음 사용 시기

# %%
df2["변환_전자담배_처음_사용_시기"] = df2["전자담배_처음_사용_시기"].map(TC_FAGE)

# %% [markdown]
# ### 전자담배 매일 사용 시기

# %%
# 항목이 동일하므로 '처음_흡연_시작_시기'와 똑같이 매핑
df2["변환_전자담배_매일_사용_시기"] = df2["전자담배_매일_사용_시기"].map(TC_FAGE)

# %% [markdown]
# ## 궐련형 전자담배 : 담배와 똑같이 처리

# %% [markdown]
# ### 궐련형_전자담배_경험

# %%
# boolean으로
df2["변환_궐련형_전자담배_경험"] = df2["궐련형_전자담배_경험"] == 1.0

# %% [markdown]
# ### 궐련형_전자담배_처음_사용_시기

# %%
df2["변환_궐련형_전자담배_처음_사용_시기"] = df2["궐련형_전자담배_처음_사용_시기"].map(TC_FAGE)

# %% [markdown]
# ### 궐련형_전자담배_매일_사용_시기

# %%
df2["변환_궐련형_전자담배_매일_사용_시기"] = df2["궐련형_전자담배_매일_사용_시기"].map(TC_FAGE)

# %% [markdown]
# # 구분

# %%
with pd.option_context('display.max_rows', None):
    display(resumetable(df2, 3))
# Out:
# 데이터셋 크기: (54653, 66)
#                       피처   데이터 타입  결측값 개수  고유값 개수    1번째 값    2번째 값    3번째 값
# 0                    OBS   object       0   54653  A100001  A100002  A100003
# 1                   조사연도  float64       0       1   2024.0   2024.0   2024.0
# 2                     시도   object       0      17       서울       서울       서울
# 3                   도시규모   object       0       3      대도시      대도시      대도시
# 4                   학교구분   object       0       2      중학교      중학교      중학교
# 5                   학교유형   object       0       3     남녀공학     남녀공학     남녀공학
# 6                    지역군   object       0      49   서울대4-3   서울대4-3   서울대4-3
# 7              주관적_건강_인지  float64       0       5      1.0      1.0      1.0
# 8              주관적_체형_인지  float64       0       5      2.0      4.0      3.0
# 9               평생_흡연_경험  float64       0       2      1.0      1.0      1.0
# 10              처음_흡연_시기  float64   50529      13      NaN      NaN      NaN
# 11                  흡연일수  float64   50442       7      NaN      NaN      NaN
# 12           매일_흡연_시작_시기  float64   53845      12      NaN      NaN      NaN
# 13                   흡연량  float64   52711       6      NaN      NaN      NaN
# 14               전자담배_경험  float64       0       2      1.0      1.0      1.0
# 15         전자담배_처음_사용_시기  float64   51058      13      NaN      NaN      NaN
# 16          전자담배_현재_사용일수  float64   51028       7      NaN      NaN      NaN
# 17         전자담배_매일_사용_시기  float64   54237      12      NaN      NaN      NaN
# 18           궐련형_전자담배_경험  float64       0       2      1.0      1.0      1.0
# 19     궐련형_전자담배_처음_사용_시기  float64   52670      13      NaN      NaN      NaN
# 20      궐련형_전자담배_현재_사용일수  float64   52638       7      NaN      NaN      NaN
# 21     궐련형_전자담배_매일_사용_시기  float64   54476      10      NaN      NaN      NaN
# 22          궐련형_전자담배_흡연량  float64   53658       6      NaN      NaN      NaN
# 23               주된_흡연장소  float64   52232       5      NaN      NaN      NaN
# 24              담배_구매_방법  float64   52232       5      NaN      NaN      NaN
# 25             담배_구매_용이성  float64       0       5      1.0      1.0      1.0
# 26              금연_시도_여부  float64   52232       2      NaN      NaN      NaN
# 27               금연홍보_없음  float64   38839       1      NaN      NaN      NaN
# 28               금연홍보_TV  float64   27276       1      2.0      2.0      2.0
# 29              금연홍보_라디오  float64   49322       1      NaN      NaN      3.0
# 30            금연홍보_TV_뉴스  float64   43375       1      4.0      NaN      4.0
# 31              금연홍보_인터넷  float64   31306       1      5.0      NaN      5.0
# 32               금연홍보_신문  float64   47918       1      6.0      NaN      6.0
# 33             금연홍보_대중교통  float64   41544       1      7.0      NaN      7.0
# 34               담배광고_잡지  float64   50569       1      1.0      NaN      NaN
# 35              담배광고_인터넷  float64   34786       1      2.0      2.0      NaN
# 36              담배광고_편의점  float64   30626       1      3.0      NaN      NaN
# 37             담배광고_슈퍼마켓  float64   44743       1      4.0      NaN      NaN
# 38               담배광고_없음  float64   35237       1      NaN      NaN      5.0
# 39               가정_간접흡연  float64       0       8      1.0      8.0      1.0
# 40               학교_간접흡연  float64       0       8      1.0      1.0      1.0
# 41             공공장소_간접흡연  float64       0       8      1.0      3.0      1.0
# 42            학교_금연교육_경험  float64       0       2      2.0      2.0      2.0
# 43               가족흡연_없음  float64   29280       1      1.0      NaN      NaN
# 44              가족흡연_아버지  float64   32631       1      NaN      2.0      2.0
# 45              가족흡연_어머니  float64   52329       1      NaN      NaN      NaN
# 46             가족흡연_형제자매  float64   51886       1      NaN      NaN      NaN
# 47              가족흡연_조부모  float64   50850       1      NaN      5.0      NaN
# 48               가족흡연_기타  float64   51061       1      NaN      NaN      NaN
# 49               가족흡연_모름  float64   53025       1      NaN      NaN      NaN
# 50                 친구_흡연  float64       0       4      1.0      1.0      1.0
# 51                   만나이  float64       0       7     13.0     13.0     13.0
# 52                    월령  float64       0      83    158.0    161.0    161.0
# 53                  학업성적  float64       0       5      1.0      4.0      1.0
# 54                  경제상태  float64       0       5      1.0      2.0      1.0
# 55                  거주형태  float64       0       5      1.0      1.0      1.0
# 56                    학년  float64       0       6      1.0      1.0      1.0
# 57           변환_평생_흡연_경험     bool       0       2     True     True     True
# 58           변환_처음_흡연_시기   object   50529      13      NaN      NaN      NaN
# 59        변환_매일_흡연_시작_시기   object   53845      12      NaN      NaN      NaN
# 60            변환_전자담배_경험     bool       0       2     True     True     True
# 61      변환_전자담배_처음_사용_시기   object   51058      13      NaN      NaN      NaN
# 62      변환_전자담배_매일_사용_시기   object   54237      12      NaN      NaN      NaN
# 63        변환_궐련형_전자담배_경험     bool       0       2     True     True     True
# 64  변환_궐련형_전자담배_처음_사용_시기   object   52670      13      NaN      NaN      NaN
# 65  변환_궐련형_전자담배_매일_사용_시기   object   54476      10      NaN      NaN      NaN

# %%
df2['금연홍보_인터넷'].value_counts(dropna=False)
# Out:
# 금연홍보_인터넷
# NaN    31306
# 5.0    23347
# Name: count, dtype: int64

# %%
col = '주된_흡연장소'
sns.countplot(data=df2, x=col)
plt.title(f'Count Plot of {col}')
plt.xticks(rotation=45);
